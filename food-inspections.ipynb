# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
from datetime import datetime, timedelta
from sklearn.linear_model import LinearRegression,LogisticRegression

# %matplotlib inline

# %%
df = pd.read_csv("DOHMH_New_York_City_Restaurant_Inspection_Results2.csv")

# %%
df.shape
# Out:
# (385226, 26)

# %%
df.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL',
#        'NTA'],
#       dtype='object')

# %%
df = df.drop(columns=['PHONE', 'BIN', 'BBL', 'NTA', 'Community Board', 'Council District', 'RECORD DATE'])

# %%
df.tail(2)
# Out:
#            CAMIS               DBA       BORO BUILDING        STREET  ZIPCODE  \
# 385224  40575519           MOLYVOS  Manhattan      871      7 AVENUE  10019.0
# 385225  50067280  LUCKY RESTAURANT     Queens     4521  PARSONS BLVD  11355.0
#
#        CUISINE DESCRIPTION INSPECTION DATE  \
# 385224               Greek      03/20/2017
# 385225             Chinese      12/26/2018
#
#                                                  ACTION VIOLATION CODE  \
# 385224  Violations were cited in the following area(s).            08C
# 385225  Violations were cited in the following area(s).            08A
#
#                                     VIOLATION DESCRIPTION CRITICAL FLAG  \
# 385224  Pesticide use not in accordance with label or ...             N
# 385225  Facility not vermin proof. Harborage or condit...             N
#
#         SCORE GRADE GRADE DATE                        INSPECTION TYPE  \
# 385224   20.0   NaN        NaN  Cycle Inspection / Initial Inspection
# ...

# %%
df['INSPECTION YEAR'] = df['INSPECTION DATE'].str.extract(r"/(\w+)$")

# %%
df['INSPECTION YEAR'] = df['INSPECTION YEAR'].str.replace('1900','not insprected yet')

# %%
df['IN-DATE'] =  pd.to_datetime(df['INSPECTION DATE'])

# %%
df['INSPECTION YEAR'].value_counts().sort_index()
# Out:
# 2013                       3
# 2014                      12
# 2015                    3944
# 2016                   62012
# 2017                   89473
# 2018                  133779
# 2019                   94670
# not insprected yet      1333
# Name: INSPECTION YEAR, dtype: int64

# %%
# df_viocode = df[['VIOLATION CODE', 'VIOLATION DESCRIPTION']]

# %%
# df_viocode.to_csv('df_viocode.csv')

# %%
df_viocode = pd.read_csv("df_viocode.csv")

# %%
df.shape
# Out:
# (385226, 21)

# %%
df18 = df[df['INSPECTION YEAR'] == '2018']

# %%
df18.to_csv('df18.csv')

# %%
df18 = pd.read_csv("df18.csv")

# %%
df[df['CAMIS'] == 41187577].sort_values(by='IN-DATE', ascending=False)
# Out:
#            CAMIS                      DBA    BORO BUILDING  \
# 95032   41187577  HANSOL NUTRITION CENTER  Queens    16026
# 312352  41187577  HANSOL NUTRITION CENTER  Queens    16026
# 283704  41187577  HANSOL NUTRITION CENTER  Queens    16026
# 255213  41187577  HANSOL NUTRITION CENTER  Queens    16026
# 246766  41187577  HANSOL NUTRITION CENTER  Queens    16026
# 32223   41187577  HANSOL NUTRITION CENTER  Queens    16026
# 177055  41187577  HANSOL NUTRITION CENTER  Queens    16026
# 225452  41187577  HANSOL NUTRITION CENTER  Queens    16026
# 200541  41187577  HANSOL NUTRITION CENTER  Queens    16026
# 112382  41187577  HANSOL NUTRITION CENTER  Queens    16026
# 79158   41187577  HANSOL NUTRITION CENTER  Queens    16026
# 337485  41187577  HANSOL NUTRITION CENTER  Queens    16026
# 335841  41187577  HANSOL NUTRITION CENTER  Queens    16026
# 88920   41187577  HANSOL NUTRITION CENTER  Queens    16026
# 261517  41187577  HANSOL NUTRITION CENTER  Queens    16026
# ...

# %%
df18 = df18.drop(columns='Unnamed: 0')

# %%
df18.sort_values(by='CAMIS', ascending=False)
# Out:
#            CAMIS                             DBA       BORO BUILDING  \
# 30692   50086910                SAMIR RESTAURANT   Brooklyn      696
# 84410   50086910                SAMIR RESTAURANT   Brooklyn      696
# 124322  50086910                SAMIR RESTAURANT   Brooklyn      696
# 125987  50086910                SAMIR RESTAURANT   Brooklyn      696
# 28877   50086910                SAMIR RESTAURANT   Brooklyn      696
# 89240   50086790                          NIUDDO     Queens     4142
# 53282   50086790                          NIUDDO     Queens     4142
# 39162   50086764        EL CLUB VALLE RESTAURANT      Bronx      352
# 50995   50086764        EL CLUB VALLE RESTAURANT      Bronx      352
# 127532  50086764        EL CLUB VALLE RESTAURANT      Bronx      352
# 13186   50086764        EL CLUB VALLE RESTAURANT      Bronx      352
# 111097  50086764        EL CLUB VALLE RESTAURANT      Bronx      352
# 37410   50086764        EL CLUB VALLE RESTAURANT      Bronx      352
# ...

# %%
df18.groupby(['CAMIS','IN-DATE']).count()
# Out:
#                      DBA  BORO  BUILDING  STREET  ZIPCODE  \
# CAMIS    IN-DATE
# 30075445 2018-05-11    2     2         2       2        2
# 30112340 2018-03-13    3     3         3       3        3
# 30191841 2018-05-16    3     3         3       3        3
# 40356018 2018-10-30    2     2         2       2        2
# 40356151 2018-10-06    3     3         3       3        3
# 40356483 2018-05-10    2     2         2       2        2
# 40356731 2018-05-16    4     4         4       4        4
# 40357217 2018-05-31    2     2         2       2        2
# 40359480 2018-09-28    2     2         2       2        2
# 40359705 2018-03-07    2     2         2       2        2
# 40360045 2018-11-27    1     1         1       1        1
# 40360076 2018-03-20    3     3         3       3        3
# 40361322 2018-03-28    4     4         4       4        4
#          2018-07-12    4     4         4       4        4
# 40361618 2018-01-24    3     3         3       3        3
# ...

# %%
df18.drop(columns=['INSPECTION DATE',]
# Out:
# Index(['Unnamed: 0', 'CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Census Tract', 'INSPECTION YEAR', 'IN-DATE'],
#       dtype='object')

# %%
# #df_test["Codes_List"] = 
# df.groupby(by=['CAMIS', 'DBA', 'INSPECTION YEAR','IN-DATE','GRADE DATE','BORO', 'BUILDING', 'STREET', 'ZIPCODE',
#        'CUISINE DESCRIPTION', 'ACTION', 'SCORE', 'GRADE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Census Tract'])['VIOLATION CODE'].value_counts().unstack() #.agg(lambda x: ', '.join(set(x)))

# %%
df_test["Total_Violations"] = df.groupby(by=['CAMIS', 'DBA', 'INSPECTION YEAR','IN-DATE','GRADE DATE','BORO', 'BUILDING', 'STREET', 'ZIPCODE',
       'CUISINE DESCRIPTION', 'ACTION', 'SCORE', 'GRADE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
       'Census Tract']).count()["VIOLATION CODE"]

# %%
df_test.reset_index(inplace=True)

# %%
df_test = df_test.drop(columns=['INSPECTION DATE', 'VIOLATION CODE', 'VIOLATION DESCRIPTION','CRITICAL FLAG', 'Codes_List'])

# %%
df_test.shape
# Out:
# (81398, 18)
